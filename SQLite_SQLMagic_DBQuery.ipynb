# %%
# Establsihing a database connection and creating a connection and a cursor object
import sqlite3
con = sqlite3.connect("FinalDB.db")
cur = con.cursor()

# %%
# Loading the ipython sql extension to initiate SQL magic
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Initiating connection between SQL magic module and the database "FinalDB.db"
# %sql sqlite:///FinalDB.db

# %%
# Download csv files, convert to dataframes using pandas, laod dataframes to the database tables

import csv
import pandas as pd

# Chicago Public Schools Data - from the local file
df_schools = pd.read_csv(r"C:\Users\OK\ChicagoPublicSchools.csv")
df_schools.to_sql("CHICAGO_PUBLIC_SCHOOLS_DATA", con, if_exists = "replace", index = False, method = "multi")
# Out:
# 566

# %%
# Chicago Census Data - from the url
df_census = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df_census.to_sql("CHICAGO_CENSUS_DATA", con, if_exists = "replace", index = False, method = "multi")
# Out:
# 78

# %%
# Chicago Crime Data - from the url
df_crime = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df_crime.to_sql("CHICAGO_CRIME_DATA", con, if_exists = "replace", index = False, method = "multi")
# Out:
# 533

# %%
# Validate database tables
# %sql SELECT name FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite:///FinalDB.db
#    sqlite:///RealWorldData.db
# Done.
# [('CHICAGO CENSUS DATA',),
#  ('CHICAGO CRIME DATA',),
#  ('CHICAGO_PUBLIC_SCHOOLS_DATA',),
#  ('CHICAGO_CENSUS_DATA',),
#  ('CHICAGO_CRIME_DATA',)]

# %%
# %sql SELECT name,type,length(type) FROM PRAGMA_TABLE_INFO('CHICAGO_PUBLIC_SCHOOLS_DATA')
# Out:
#  * sqlite:///FinalDB.db
#    sqlite:///RealWorldData.db
# Done.
# [('School_ID', 'INTEGER', 7),
#  ('NAME_OF_SCHOOL', 'TEXT', 4),
#  ('Elementary, Middle, or High School', 'TEXT', 4),
#  ('Street_Address', 'TEXT', 4),
#  ('City', 'TEXT', 4),
#  ('State', 'TEXT', 4),
#  ('ZIP_Code', 'INTEGER', 7),
#  ('Phone_Number', 'TEXT', 4),
#  ('Link', 'TEXT', 4),
#  ('Network_Manager', 'TEXT', 4),
#  ('Collaborative_Name', 'TEXT', 4),
#  ('Adequate_Yearly_Progress_Made_', 'TEXT', 4),
#  ('Track_Schedule', 'TEXT', 4),
#  ('CPS_Performance_Policy_Status', 'TEXT', 4),
#  ('CPS_Performance_Policy_Level', 'TEXT', 4),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'TEXT', 4),
#  ('Safety_Icon', 'TEXT', 4),
#  ('SAFETY_SCORE', 'REAL', 4),
#  ('Family_Involvement_Icon', 'TEXT', 4),
#  ('Family_Involvement_Score', 'TEXT', 4),
#  ('Environment_Icon', 'TEXT', 4),
#  ('Environment_Score', 'REAL', 4),
#  ('Instruction_Icon', 'TEXT', 4),
#  ('Instruction_Score', 'REAL', 4),
#  ('Leaders_Icon', 'TEXT', 4),
# ...

# %%
# %sql SELECT name,type,length(type) FROM PRAGMA_TABLE_INFO('CHICAGO_CENSUS_DATA')
# Out:
#  * sqlite:///FinalDB.db
#    sqlite:///RealWorldData.db
# Done.
# [('COMMUNITY_AREA_NUMBER', 'REAL', 4),
#  ('COMMUNITY_AREA_NAME', 'TEXT', 4),
#  ('PERCENT_OF_HOUSING_CROWDED', 'REAL', 4),
#  ('PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'REAL', 4),
#  ('PERCENT_AGED_16__UNEMPLOYED', 'REAL', 4),
#  ('PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'REAL', 4),
#  ('PERCENT_AGED_UNDER_18_OR_OVER_64', 'REAL', 4),
#  ('PER_CAPITA_INCOME', 'INTEGER', 7),
#  ('HARDSHIP_INDEX', 'REAL', 4)]

# %%
# %sql SELECT name,type,length(type) FROM PRAGMA_TABLE_INFO('CHICAGO_CRIME_DATA')
# Out:
#  * sqlite:///FinalDB.db
#    sqlite:///RealWorldData.db
# Done.
# [('ID', 'INTEGER', 7),
#  ('CASE_NUMBER', 'TEXT', 4),
#  ('DATE', 'TEXT', 4),
#  ('BLOCK', 'TEXT', 4),
#  ('IUCR', 'TEXT', 4),
#  ('PRIMARY_TYPE', 'TEXT', 4),
#  ('DESCRIPTION', 'TEXT', 4),
#  ('LOCATION_DESCRIPTION', 'TEXT', 4),
#  ('ARREST', 'INTEGER', 7),
#  ('DOMESTIC', 'INTEGER', 7),
#  ('BEAT', 'INTEGER', 7),
#  ('DISTRICT', 'INTEGER', 7),
#  ('WARD', 'REAL', 4),
#  ('COMMUNITY_AREA_NUMBER', 'REAL', 4),
#  ('FBICODE', 'TEXT', 4),
#  ('X_COORDINATE', 'REAL', 4),
#  ('Y_COORDINATE', 'REAL', 4),
#  ('YEAR', 'INTEGER', 7),
#  ('LATITUDE', 'REAL', 4),
#  ('LONGITUDE', 'REAL', 4),
#  ('LOCATION', 'TEXT', 4)]

# %%
# Find the total number of crimes recorded in the CRIME table.
# %sql SELECT count(ID) FROM CHICAGO_CRIME_DATA
# Out:
#  * sqlite:///FinalDB.db
#    sqlite:///RealWorldData.db
# Done.
# [(533,)]

# %%
# List community area names and numbers with per capita income less than 11000.

# %sql select Community_Area_Name, Community_Area_Number from CHICAGO_CENSUS_DATA \
where "Per_Capita_Income" < 11000 \
group by "Community_Area_Name"
# Out:
#  * sqlite:///FinalDB.db
#    sqlite:///RealWorldData.db
# Done.
# [('Fuller Park', 37.0),
#  ('Riverdale', 54.0),
#  ('South Lawndale', 30.0),
#  ('West Garfield Park', 26.0)]

# %%
# List the type of schools along with the maximum safety score for each school.
# %sql select Name_of_School, Safety_Score from CHICAGO_PUBLIC_SCHOOLS_DATA where \
Safety_Score = (select MAX(Safety_Score) from CHICAGO_PUBLIC_SCHOOLS_DATA)
# Out:
#  * sqlite:///FinalDB.db
#    sqlite:///RealWorldData.db
# Done.
# [('Abraham Lincoln Elementary School', 99.0),
#  ('Alexander Graham Bell Elementary School', 99.0),
#  ('Annie Keller Elementary Gifted Magnet School', 99.0),
#  ('Augustus H Burley Elementary School', 99.0),
#  ('Edgar Allan Poe Elementary Classical School', 99.0),
#  ('Edgebrook Elementary School', 99.0),
#  ('Ellen Mitchell Elementary School', 99.0),
#  ('James E McDade Elementary Classical School', 99.0),
#  ('James G Blaine Elementary School', 99.0),
#  ('LaSalle Elementary Language Academy', 99.0),
#  ('Mary E Courtenay Elementary Language Arts Center', 99.0),
#  ('Northside College Preparatory High School', 99.0),
#  ('Northside Learning Center High School', 99.0),
#  ('Norwood Park Elementary School', 99.0),
#  ('Oriole Park Elementary School', 99.0),
#  ('Sauganash Elementary School', 99.0),
#  ('Stephen Decatur Classical Elementary School', 99.0),
#  ('Talman Elementary School', 99.0),
# ...

# %%
# Use a sub-query to find the name of the community area with highest hardship index.
# %sql select COMMUNITY_AREA_NAME from CHICAGO_CENSUS_DATA where \
HARDSHIP_INDEX IN (select MAX(HARDSHIP_INDEX) from CHICAGO_CENSUS_DATA)
# Out:
#  * sqlite:///FinalDB.db
#    sqlite:///RealWorldData.db
# Done.
# [('Riverdale',)]

# %%
# List 5 community areas with highest % of households below poverty line
df_census["PERCENT_HOUSEHOLDS_BELOW_POVERTY"]

# %sql SELECT Community_Area_Name, PERCENT_HOUSEHOLDS_BELOW_POVERTY \
from CHICAGO_CENSUS_DATA \
order by PERCENT_HOUSEHOLDS_BELOW_POVERTY desc \
limit 5
# Out:
#  * sqlite:///FinalDB.db
#    sqlite:///RealWorldData.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]
